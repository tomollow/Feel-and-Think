# %% [markdown]
# <a href="https://colab.research.google.com/github/tomollow/Feel-and-Think/blob/main/t_SNE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.manifold import TSNE

# MNISTデータをロード
digits = datasets.load_digits()

# t-SNEで2次元に次元削減
tsne = TSNE(n_components=2, random_state=42)
digits_tsne = tsne.fit_transform(digits.data)

# 結果のプロット
plt.figure(figsize=(10, 8))
colors = ["#476A2A", "#7851B8", "#BD3430", "#4A2D4E", "#875525",
          "#A83683", "#4E655E", "#853541", "#3A3120", "#535D8E"]
for i, c in zip(range(10), colors):
    plt.scatter(digits_tsne[digits.target == i, 0],
                digits_tsne[digits.target == i, 1], c=c, label=i)
plt.xlabel('t-SNE feature 1')
plt.ylabel('t-SNE feature 2')
plt.legend()
plt.show()
